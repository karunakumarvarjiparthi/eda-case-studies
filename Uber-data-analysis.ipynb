# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =  pd.read_csv(r"C:\Users\91934\Downloads\archive\ncr_ride_bookings.csv")
df
# Out:
#               Date      Time    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Date                               150000 non-null  object
#  1   Time                               150000 non-null  object
#  2   Booking ID                         150000 non-null  object
#  3   Booking Status                     150000 non-null  object
#  4   Customer ID                        150000 non-null  object
#  5   Vehicle Type                       150000 non-null  object
#  6   Pickup Location                    150000 non-null  object
#  7   Drop Location                      150000 non-null  object
#  8   Avg VTAT                           139500 non-null  float64
#  9   Avg CTAT                           102000 non-null  float64
#  10  Cancelled Rides by Customer        10500 non-null   float64
# ...

# %%
df.describe()
df1 = df

# %%
df1
# Out:
#               Date      Time    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                              10500
# Avg CTAT                              48000
# Cancelled Rides by Customer          139500
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver            123000
# Driver Cancellation Reason           123000
# Incomplete Rides                     141000
# Incomplete Rides Reason              141000
# Booking Value                         48000
# Ride Distance                         48000
# Driver Ratings                        57000
# Customer Rating                       57000
# Payment Method                        48000
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df['Drop Location'].fillna("unknown",inplace = True)
# Out:
# C:\Users\91934\AppData\Local\Temp\ipykernel_23308\3941478859.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Drop Location'].fillna("unknown",inplace = True)

# %%
df['Pickup Location'].fillna("unknown",inplace = True)

# %%
df['Driver Ratings'].fillna(df['Driver Ratings'].mean(), inplace=True)

# %%
df['Customer Rating']
# Out:
# 0         4.404584
# 1         4.404584
# 2         4.900000
# 3         5.000000
# 4         4.300000
#             ...
# 149995    4.100000
# 149996    5.000000
# 149997    4.400000
# 149998    3.700000
# 149999    4.900000
# Name: Customer Rating, Length: 150000, dtype: float64

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
print(df['Date'].dtype)
# Out:
# datetime64[ns]

# %%
print(df1['Time'].dtype)
print(type(df1['Time'].iloc[0]))
# Out:
# object
# <class 'str'>

# %%
df1['Time'] = pd.to_datetime(df1['Time'], format='%H:%M:%S', errors='coerce').dt.time

# %%
print(df1['Time'].dtype)
print(type(df1['Time'].iloc[0]))
df2 = df
df2
# Out:
# object
# <class 'datetime.time'>
#              Date      Time    Booking ID   Booking Status   Customer ID  \
# 0      2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1      2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2      2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3      2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4      2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...           ...       ...           ...              ...           ...
# 149995 2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996 2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997 2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998 2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999 2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
# ...

# %%
df1['Time'] = pd.to_datetime(df1['Time'], format='%H:%M:%S', errors='coerce').dt.time
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df1['Time'] = pd.to_datetime(df1['Time'], format='%H:%M:%S', errors='coerce').dt.time
#
# NameError: name 'df1' is not defined

# %%
print(df['Time'].dtype)
print(type(df['Time'].iloc[0]))
# Out:
# object
# <class 'datetime.time'>

# %%
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str))

# %%
df['DateTime']
# Out:
# 0        2024-03-23 12:29:38
# 1        2024-11-29 18:01:39
# 2        2024-08-23 08:56:10
# 3        2024-10-21 17:17:25
# 4        2024-09-16 22:08:00
#                  ...
# 149995   2024-11-11 19:34:01
# 149996   2024-11-24 15:55:09
# 149997   2024-09-18 10:55:15
# 149998   2024-10-05 07:53:34
# 149999   2024-03-10 15:38:03
# Name: DateTime, Length: 150000, dtype: datetime64[ns]

# %%
df['Booking Value'] = pd.to_numeric(df['Booking Value'], errors='coerce')
# Out:
# 0            NaN
# 1          237.0
# 2          627.0
# 3          416.0
# 4          737.0
#            ...
# 149995     475.0
# 149996    1093.0
# 149997     852.0
# 149998     333.0
# 149999     806.0
# Name: Booking Value, Length: 150000, dtype: float64

# %%
df['Ride Distance'] = pd.to_numeric(df['Ride Distance'], errors='coerce')
# Out:
# 0           NaN
# 1          5.73
# 2         13.58
# 3         34.02
# 4         48.21
#           ...
# 149995    40.08
# 149996    21.31
# 149997    15.93
# 149998    45.54
# 149999    21.19
# Name: Ride Distance, Length: 150000, dtype: float64

# %%
df.drop_duplicates(subset=['Booking ID'], inplace=True)

# %%
df['Booking Status'] = df['Booking Status'].str.strip().str.lower()

# %%
df['Payment Method'] = df['Payment Method'].str.title()

# %%
sns.boxplot(df['Booking Value'])
# Out:
# <Axes: ylabel='Booking Value'>

# %%
q1 = df['Booking Value'].quantile(0.01)
q99 = df['Booking Value'].quantile(0.99)
df = df[(df['Booking Value'] >= q1) & (df['Booking Value'] <= q99)]

# %%
df['Hour'] = pd.to_datetime(df2['DateTime'], errors='coerce').dt.hour
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df['Hour'] = pd.to_datetime(df2['DateTime'], errors='coerce').dt.hour
#
# NameError: name 'df2' is not defined

# %%
df1['Weekday']
# Out:
# 0          Saturday
# 1            Friday
# 2            Friday
# 3            Monday
# 4            Monday
#             ...
# 149995       Monday
# 149996       Sunday
# 149997    Wednesday
# 149998     Saturday
# 149999       Sunday
# Name: Weekday, Length: 148767, dtype: object

# %%
df1['Ride Completed']
# Out:
# 0         0
# 1         0
# 2         1
# 3         1
# 4         1
#          ..
# 149995    1
# 149996    1
# 149997    1
# 149998    1
# 149999    1
# Name: Ride Completed, Length: 148767, dtype: int64

# %%
df1
# Out:
#              Date      Time    Booking ID   Booking Status   Customer ID  \
# 0      2024-03-23  12:29:38  "CNR5884300"  no driver found  "CID1982111"
# 1      2024-11-29  18:01:39  "CNR1326809"       incomplete  "CID4604802"
# 2      2024-08-23  08:56:10  "CNR8494506"        completed  "CID9202816"
# 3      2024-10-21  17:17:25  "CNR8906825"        completed  "CID2610914"
# 4      2024-09-16  22:08:00  "CNR1950162"        completed  "CID9933542"
# ...           ...       ...           ...              ...           ...
# 149995 2024-11-11  19:34:01  "CNR6500631"        completed  "CID4337371"
# 149996 2024-11-24  15:55:09  "CNR2468611"        completed  "CID2325623"
# 149997 2024-09-18  10:55:15  "CNR6358306"        completed  "CID9925486"
# 149998 2024-10-05  07:53:34  "CNR3030099"        completed  "CID9415487"
# 149999 2024-03-10  15:38:03  "CNR3447390"        completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
print(df['Time'].head(10))
# Out:
# 1     18:01:39
# 2     08:56:10
# 3     17:17:25
# 4     22:08:00
# 5     09:44:56
# 6     15:45:58
# 7     17:37:37
# 9     19:06:48
# 10    16:24:12
# 13    19:29:39
# Name: Time, dtype: object

# %%
df['Time'] = pd.to_datetime(df['Time'], errors='coerce')
df['Hour'] = df['Time'].dt.hour

# %%
print(df['Time'].head(10))
# Out:
# 1    NaT
# 2    NaT
# 3    NaT
# 4    NaT
# 5    NaT
# 6    NaT
# 7    NaT
# 9    NaT
# 10   NaT
# 13   NaT
# Name: Time, dtype: datetime64[ns]

# %%
df['Time'] = pd.to_datetime(df['Time'], format="%H:%M:%S", errors='coerce')

# %%
print(df['Time'].head(10))
# Out:
# 1    NaT
# 2    NaT
# 3    NaT
# 4    NaT
# 5    NaT
# 6    NaT
# 7    NaT
# 9    NaT
# 10   NaT
# 13   NaT
# Name: Time, dtype: datetime64[ns]

# %%
print(df['Time'].dropna().astype(str).unique()[:10])
# Out:
# []

# %%
print(df['Time'].head(10))
# Out:
# 1    NaT
# 2    NaT
# 3    NaT
# 4    NaT
# 5    NaT
# 6    NaT
# 7    NaT
# 9    NaT
# 10   NaT
# 13   NaT
# Name: Time, dtype: datetime64[ns]

# %%
df['Time'] = pd.to_datetime(df['Time'], format="%H:%M:%S", errors='coerce')

# %%
print(df['Time'].head(10))
# Out:
# 1    NaT
# 2    NaT
# 3    NaT
# 4    NaT
# 5    NaT
# 6    NaT
# 7    NaT
# 9    NaT
# 10   NaT
# 13   NaT
# Name: Time, dtype: datetime64[ns]

# %%
df['Time'] = pd.to_datetime(df['Time'], format="%H:%M:%S", errors='coerce')

# %%
df['Hour'] = df['Time'].dt.hour
df['Minute'] = df['Time'].dt.minute
df['Second'] = df['Time'].dt.second

# %%
df['Time']
# Out:
# 1        NaT
# 2        NaT
# 3        NaT
# 4        NaT
# 5        NaT
#           ..
# 149995   NaT
# 149996   NaT
# 149997   NaT
# 149998   NaT
# 149999   NaT
# Name: Time, Length: 97179, dtype: datetime64[ns]

# %%
df['Time'] = df['Time'].dt.strftime("%H:%M:%S")

# %%
df['Time']
# Out:
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
#          ...
# 149995    NaN
# 149996    NaN
# 149997    NaN
# 149998    NaN
# 149999    NaN
# Name: Time, Length: 97179, dtype: object

# %%
df['Time_raw'] = df['Time']  # backup original
df['Time'] = pd.to_datetime(df['Time'], errors='coerce').dt.time

# %%
df['Time']
# Out:
# 0         12:29:38
# 1         18:01:39
# 2         08:56:10
# 3         17:17:25
# 4         22:08:00
#             ...
# 149995    19:34:01
# 149996    15:55:09
# 149997    10:55:15
# 149998    07:53:34
# 149999    15:38:03
# Name: Time, Length: 150000, dtype: object

# %%
df
# Out:
#               Date      Time    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
print(df['Time'].dtype)
print(type(df['Time'].iloc[0]))
# Out:
# object
# <class 'datetime.time'>
